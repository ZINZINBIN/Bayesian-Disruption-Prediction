# %%
import sys, os
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# move directory
os.chdir("..")

# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
disrupt_data = pd.read_csv("./dataset/Bayesian_Disruption_Shot_List.csv")
ces_data = pd.read_csv('./dataset/KSTAR_Disruption_ts_data_ces.csv')
diag_data = pd.read_pickle("./dataset/Bayesian_Disruption_diag.pkl")
ece_data = pd.read_pickle('./dataset/Bayesian_Disruption_ece.pkl')
efit_data = pd.read_pickle("./dataset/Bayesian_Disruption_efit.pkl")

# %%
# shot info plot
from src.utils.utility import plot_shot_info
from src.config import Config

config = Config()

for shot in disrupt_data.shot.unique():
    save_path = "./results/analysis_experiments/"
    plot_shot_info(config.filepath, int(shot), save_path)

# %%
import matplotlib.pyplot as plt
import numpy as np

shot_num = 31888
t_tq = disrupt_data[disrupt_data.shot == shot_num].t_tmq.values[0]
t_cq = disrupt_data[disrupt_data.shot == shot_num].t_ip_min_fault.values[0]

ces = ces_data[ces_data.shot == shot_num]
diag = diag_data[diag_data.shot == shot_num]
ece = ece_data[ece_data.shot == shot_num]

# %%
plt.figure(1)
plt.plot(ces.time, ces['\\CES_VT01'])
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')

plt.figure(2)
plt.plot(diag.time, diag['\\LM01'], label = 'LM01')
plt.plot(diag.time, diag['\\LM02'], label = 'LM02')
plt.plot(diag.time, diag['\\LM03'], label = 'LM03')
plt.plot(diag.time, diag['\\LM04'], label = 'LM04')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')

# %%
shot_num = 30312
t_tq = disrupt_data[disrupt_data.shot == shot_num].t_tmq.values[0]
t_cq = disrupt_data[disrupt_data.shot == shot_num].t_ip_min_fault.values[0]

ces = ces_data[ces_data.shot == shot_num]
diag = diag_data[diag_data.shot == shot_num]
ece = ece_data[ece_data.shot == shot_num]
efit = efit_data[efit_data.shot == shot_num]

plt.figure(1)
plt.plot(ces.time, ces['\\CES_VT01'])
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')

plt.figure(2)
plt.plot(diag.time, diag['\\LM01'], label = 'LM01')
plt.plot(diag.time, diag['\\LM02'], label = 'LM02')
plt.plot(diag.time, diag['\\LM03'], label = 'LM03')
plt.plot(diag.time, diag['\\LM04'], label = 'LM04')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')

# %%
plt.plot(ece.time, ece['\\ECE67'], label = 'R=1.808m (Core)')
plt.plot(ece.time, ece['\\ECE63'], label = 'R=1.883m')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')
plt.axvline(x=t_tq - 0.005,ymin=0,ymax=1,c='b')
plt.xlim([t_tq - 1.0, t_cq])
# Out:
# (10.558, 11.568)

# %%
plt.plot(ece.time, ece['\\ECE67'], label = 'R=1.808m (Core)')
plt.plot(ece.time, ece['\\ECE63'], label = 'R=1.883m')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')
plt.axvline(x=t_tq - 0.005,ymin=0,ymax=1,c='b')
plt.xlim([4, 10])
# Out:
# (4.0, 10.0)

# %%
plt.plot(diag.time, diag['\\EC1_PWR'], label = 'ECH01')
plt.plot(diag.time, diag['\\EC2_PWR'], label = 'ECH02')
plt.plot(diag.time, diag['\\EC3_PWR'], label = 'ECH03')
plt.plot(diag.time, diag['\\EC4_PWR'], label = 'ECH04')
plt.plot(diag.time, diag['\\EC5_PWR'], label = 'ECH05')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')
plt.axvline(x=t_tq - 0.005,ymin=0,ymax=1,c='b')
plt.xlim([t_tq - 0.04, t_cq])
# Out:
# (11.518, 11.568)

# %%
plt.plot(efit.time, efit['\\q95'], label = 'q95')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')
plt.ylim([0, 10.0])
plt.xlim([t_tq - 0.04, t_cq])
# Out:
# (11.518, 11.568)

# %%
plt.plot(efit.time, efit['\\troyon'], label = 'Troyon')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')
plt.ylim([0, 2.0])
plt.xlim([t_tq - 0.04, t_cq])
# Out:
# (11.518, 11.568)

# %%
shot_num = 29069
t_tq = disrupt_data[disrupt_data.shot == shot_num].t_tmq.values[0]
t_cq = disrupt_data[disrupt_data.shot == shot_num].t_ip_min_fault.values[0]

ces = ces_data[ces_data.shot == shot_num]
diag = diag_data[diag_data.shot == shot_num]

plt.figure(1)
plt.plot(ces.time, ces['\\CES_VT02'])
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')

plt.figure(2)
plt.plot(diag.time, diag['\\LM01'], label = 'LM01')
plt.plot(diag.time, diag['\\LM02'], label = 'LM02')
plt.plot(diag.time, diag['\\LM03'], label = 'LM03')
plt.plot(diag.time, diag['\\LM04'], label = 'LM04')
plt.legend()
plt.axvline(x=t_tq,ymin=0,ymax=1,c='r')
plt.axvline(x=t_cq,ymin=0,ymax=1,c='k')

# %% [markdown]
# ### Operation regime
# - Regime 1: safe regime
# - Regime 2: Warning regime or therma quench

# %%
import matplotlib.pyplot as plt
import seaborn as sns

disrupt_data = pd.read_csv("./dataset/Bayesian_Disruption_Shot_List_revised.csv")
efit_data = pd.read_pickle("./dataset/Bayesian_Disruption_efit.pkl")

shot_list = disrupt_data.shot.unique()
tag_list = []

efit_data = efit_data[efit_data.shot.isin(shot_list)]

for shot_num in shot_list:
    t_warning = disrupt_data[disrupt_data.shot == shot_num].t_warning.values[0]
    tftsrt = disrupt_data[disrupt_data.shot == shot_num].t_flattop_start.values[0]
    t_tq = disrupt_data[disrupt_data.shot == shot_num].t_tmq.values[0]
    t_cq = disrupt_data[disrupt_data.shot == shot_num].t_ip_min_fault.values[0]

    t = efit_data[efit_data.shot == shot_num].time.values
    
    def func(x):
        if x > t_tq:
            return 'Disruptive'
        elif x < t_tq and x > tftsrt:    
            return 'Normal'
        else:
            return 'Flattop'
    
    tag = efit_data[efit_data.shot == shot_num]['time'].apply(lambda x : func(x)).values
    tag_list.append(tag)

efit_data['tag'] = np.concatenate(tag_list)

# %%
operational = efit_data[efit_data.tag != 'Flattop'].groupby(['shot','tag']).mean()[['\\nG','\\troyon','\\q95']]

# %%
sns.scatterplot(x = '\\zxpt1', y = '\\troyon', data = operational, hue = 'tag')
# Out:
# <AxesSubplot:xlabel='\\zxpt1', ylabel='\\troyon'>

# %%
sns.scatterplot(x = '\\nG', y = '\\troyon', data = operational, hue = 'tag')
# Out:
# <AxesSubplot:xlabel='\\nG', ylabel='\\troyon'>

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

operational = efit_data[efit_data.tag != 'Flattop'].groupby(['shot','tag']).mean()[['\\nG','\\troyon','\\q95','\\zxpt2','\\zxpt1','\\rxpt2','\\rxpt1']]

tSNE = TSNE(n_components=2, perplexity=64)
v = tSNE.fit_transform(operational.values)

operational['x1'] = v[:,0]
operational['x2'] = v[:,1]

plt.figure(1, figsize = (9,5))
sns.scatterplot(x = 'x1', y = 'x2', data = operational, hue = 'tag')
plt.savefig("./results/analysis_file/tSNE_operation_regime.eps")
plt.savefig("./results/analysis_file/tSNE_operation_regime.png")
# Out:
# /home/zinzinbin/anaconda3/envs/research-env/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/zinzinbin/anaconda3/envs/research-env/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sns.histplot(x = '\\troyon', data = efit_data[efit_data.tag != 'Flattop'], hue = 'tag', kde = True, stat = 'probability', common_norm=False, binwidth=0.01)
# Out:
# <AxesSubplot:xlabel='\\troyon', ylabel='Probability'>

# %%
sns.histplot(x = '\\nG', data = efit_data[efit_data.tag != 'Flattop'], hue = 'tag', kde = True, stat = 'probability', common_norm=False, binwidth=0.01)
# Out:
# <AxesSubplot:xlabel='\\nG', ylabel='Probability'>

# %%
sns.histplot(x = '\\q95', data = efit_data[efit_data.tag != 'Flattop'], hue = 'tag', kde = True, stat = 'probability', common_norm=False, binwidth=0.01)
# Out:
# <AxesSubplot:xlabel='\\q95', ylabel='Probability'>

# %%
sns.histplot(x = '\\q95', data = operational, hue = 'tag', stat = 'probability', common_norm=False)
# Out:
# <AxesSubplot:xlabel='\\q95', ylabel='Probability'>

# %%
sns.histplot(x = '\\nG', data = operational, hue = 'tag', kde = True, stat = 'probability', common_norm=False, binwidth=0.01)
# Out:
# <AxesSubplot:xlabel='\\nG', ylabel='Probability'>

# %%
sns.histplot(x = '\\zxpt2', data = operational, hue = 'tag', stat = 'probability', common_norm=False, binwidth=0.01)
plt.xlim([-0.5,1.5])
# Out:
# (-0.5, 1.5)

# %%
sns.histplot(x = '\\zxpt1', data = operational, hue = 'tag', stat = 'probability', common_norm=False, binwidth=0.01)
plt.xlim([-2,-0.5])
# Out:
# (-2.0, -0.5)

# %%
# shot information
from src.config import Config
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

config = Config()
filepath = config.filepath

data_disrupt = pd.read_csv(filepath['disrupt'], encoding = "euc-kr")    
data_efit = pd.read_csv(filepath['efit']) if filepath['efit'].split(".")[-1] == "csv" else pd.read_pickle(filepath['efit'])
data_ece = pd.read_csv(filepath['ece']) if filepath['ece'].split(".")[-1] == "csv" else pd.read_pickle(filepath['ece'])
data_diag = pd.read_csv(filepath['diag']) if filepath['diag'].split(".")[-1] == "csv" else pd.read_pickle(filepath['diag'])

# %%
shot_num = 30312
tTQend = data_disrupt[data_disrupt.shot == shot_num].t_tmq.values[0]
tftsrt = data_disrupt[data_disrupt.shot == shot_num].t_flattop_start.values[0]
tipminf = data_disrupt[data_disrupt.shot == shot_num].t_ip_min_fault.values[0]

t_disrupt = tTQend
t_current = tipminf

plot_efit = data_efit[data_efit.shot == shot_num]
plot_ece = data_ece[data_ece.shot == shot_num]
plot_diag = data_diag[data_diag.shot == shot_num]

tl = tTQend - 0.35
tr = tipminf

# plot the disruption probability with plasma status
fig = plt.figure(figsize = (16, 10))
fig.suptitle("Disruption prediction with shot : {}".format(shot_num))
gs = GridSpec(nrows = 2, ncols = 3)

# EFIT plot : betap, internal inductance, q95, plasma current
# plasma current
ax_ip = fig.add_subplot(gs[0,0])
ln1 = ax_ip.plot(plot_diag['time'], plot_diag['\\RC03'].abs(), label = 'Ip')

ax_iv = ax_ip.twinx()
ax_ip.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_ip.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")

ln2 = ax_iv.plot(plot_diag['time'], plot_diag['\\VCM03'].abs() - plot_diag['\\RC03'].abs(), c = 'r', label = 'Iv')
lns = ln1 + ln2
labs = [l.get_label() for l in lns]
ax_ip.legend(lns, labs, loc = 'upper left')
ax_ip.set_ylabel("Ip")
ax_ip.set_xlim([tl,tr])

# q95
ax_q95 = fig.add_subplot(gs[1,0])
ax_q95.plot(plot_efit['time'], plot_efit['\\q95'], label = 'q95')
ax_q95.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_q95.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_q95.set_ylim([0, 10.0])
ax_q95.set_ylabel("q95")
ax_q95.set_xlabel("time(unit:s)")
ax_q95.legend(loc = 'upper left')
ax_q95.set_xlim([tl,tr])

# ECE part
ax_ece = fig.add_subplot(gs[0,1])
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE67'].ewm(com=0.5).mean(), label = 'R=1.808m (Core)')
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE64'].ewm(com=0.5).mean(), label = 'R=1.863m')
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE63'].ewm(com=0.5).mean(), label = 'R=1.883m')
ax_ece.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_ece.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_ece.set_ylabel("ECE(unit:KeV)")
ax_ece.legend(loc = 'upper left')
ax_ece.set_xlim([tl,tr])

ax_tci = fig.add_subplot(gs[1,1])

if int(data_disrupt[data_disrupt.shot == shot_num].Year) == 2018:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci05'], label = 'TCI05(R=2.16m)')
    
elif int(data_disrupt[data_disrupt.shot == shot_num].Year) == 2019:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci03'], label = 'TCI03(R=1.91m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci04'], label = 'TCI04(R=2.04m)')   
    
else:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci03'], label = 'TCI03(R=1.91m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci04'], label = 'TCI04(R=2.04m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci05'], label = 'TCI05(R=2.16m)')
    
ax_tci.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_tci.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_tci.set_ylabel("ne-TCI(unit:$10^{19}$ $m^{-3}$)")
ax_tci.set_xlabel("time(unit:s)")
ax_tci.legend(loc = 'upper left')
ax_tci.set_xlim([tl,tr])

# Diagnostic part
# Stored energy
ax_w = fig.add_subplot(gs[0,2])
ax_w.plot(plot_diag['time'], plot_diag['\\WTOT_DLM03'], label = 'Stored energy')
ax_w.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_w.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_w.legend(loc = 'upper left')
ax_w.set_xlim([tl,tr])

# Bolometer
ax_bol = fig.add_subplot(gs[1,2])
ax_bol.plot(plot_diag['time'], plot_diag['\\ax3_bolo02:FOO'] / plot_diag['\\ax3_bolo02:FOO'].abs().max(), label = 'AXUV bolometer')
ax_bol.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_bol.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_bol.set_xlabel("time(unit:s)")
ax_bol.legend(loc = 'upper left')
ax_bol.set_ylim([0.2,0.9])
ax_bol.set_xlim([tl,tr])

fig.tight_layout()
plt.show()

# %%
shot_num = 30312
tTQend = data_disrupt[data_disrupt.shot == shot_num].t_tmq.values[0]
tftsrt = data_disrupt[data_disrupt.shot == shot_num].t_flattop_start.values[0]
tipminf = data_disrupt[data_disrupt.shot == shot_num].t_ip_min_fault.values[0]

t_warning = 10.880
t_disrupt = tTQend
t_current = tipminf

plot_efit = data_efit[data_efit.shot == shot_num]
plot_ece = data_ece[data_ece.shot == shot_num]
plot_diag = data_diag[data_diag.shot == shot_num]

tl = tTQend - 2.0
tr = tipminf

# plot the disruption probability with plasma status
fig = plt.figure(figsize = (16, 10))
fig.suptitle("Disruption prediction with shot : {}".format(shot_num))
gs = GridSpec(nrows = 2, ncols = 3)

# EFIT plot : betap, internal inductance, q95, plasma current
# plasma current
ax_ip = fig.add_subplot(gs[0,0])
ln1 = ax_ip.plot(plot_diag['time'], plot_diag['\\RC03'].abs(), label = 'Ip')

ax_iv = ax_ip.twinx()
ax_ip.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_ip.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_ip.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")

ln2 = ax_iv.plot(plot_diag['time'], plot_diag['\\VCM03'].abs() - plot_diag['\\RC03'].abs(), c = 'r', label = 'Iv')
lns = ln1 + ln2
labs = [l.get_label() for l in lns]
ax_ip.legend(lns, labs, loc = 'upper left')
ax_ip.set_ylabel("Ip")
ax_ip.set_xlim([tl,tr])

# q95
ax_q95 = fig.add_subplot(gs[1,0])
ax_q95.plot(plot_efit['time'], plot_efit['\\q95'], label = 'q95')
ax_q95.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_q95.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_q95.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_q95.set_ylim([0, 10.0])
ax_q95.set_ylabel("q95")
ax_q95.set_xlabel("time(unit:s)")
ax_q95.legend(loc = 'upper left')
ax_q95.set_xlim([tl,tr])

# ECE part
ax_ece = fig.add_subplot(gs[0,1])
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE67'].ewm(com=0.5).mean(), label = 'R=1.808m (Core)')
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE64'].ewm(com=0.5).mean(), label = 'R=1.863m')
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE63'].ewm(com=0.5).mean(), label = 'R=1.883m')
ax_ece.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_ece.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_ece.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_ece.set_ylabel("ECE(unit:KeV)")
ax_ece.legend(loc = 'upper left')
ax_ece.set_xlim([tl,tr])

ax_tci = fig.add_subplot(gs[1,1])

if int(data_disrupt[data_disrupt.shot == shot_num].Year) == 2018:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci05'], label = 'TCI05(R=2.16m)')
    
elif int(data_disrupt[data_disrupt.shot == shot_num].Year) == 2019:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci03'], label = 'TCI03(R=1.91m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci04'], label = 'TCI04(R=2.04m)')   
    
else:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci03'], label = 'TCI03(R=1.91m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci04'], label = 'TCI04(R=2.04m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci05'], label = 'TCI05(R=2.16m)')
    
ax_tci.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_tci.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_tci.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_tci.set_ylabel("ne-TCI(unit:$10^{19}$ $m^{-3}$)")
ax_tci.set_xlabel("time(unit:s)")
ax_tci.legend(loc = 'upper left')
ax_tci.set_xlim([tl,tr])

# Diagnostic part
# Stored energy
ax_w = fig.add_subplot(gs[0,2])
ax_w.plot(plot_diag['time'], plot_diag['\\WTOT_DLM03'], label = 'Stored energy')
ax_w.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_w.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_w.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_w.legend(loc = 'upper left')
ax_w.set_xlim([tl,tr])

# Bolometer
ax_bol = fig.add_subplot(gs[1,2])
ax_bol.plot(plot_diag['time'], plot_diag['\\ax3_bolo02:FOO'] / plot_diag['\\ax3_bolo02:FOO'].abs().max(), label = 'AXUV bolometer')
ax_bol.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_bol.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_bol.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_bol.set_xlabel("time(unit:s)")
ax_bol.legend(loc = 'upper left')
ax_bol.set_ylim([0.2,0.9])
ax_bol.set_xlim([tl,tr])

fig.tight_layout()
plt.show()

# %%
shot_num = 31888
tTQend = data_disrupt[data_disrupt.shot == shot_num].t_tmq.values[0]
tftsrt = data_disrupt[data_disrupt.shot == shot_num].t_flattop_start.values[0]
tipminf = data_disrupt[data_disrupt.shot == shot_num].t_ip_min_fault.values[0]

t_warning = 6.990
t_disrupt = tTQend
t_current = tipminf

plot_efit = data_efit[data_efit.shot == shot_num]
plot_ece = data_ece[data_ece.shot == shot_num]
plot_diag = data_diag[data_diag.shot == shot_num]

tl = tTQend - 1.5
tr = tipminf

# plot the disruption probability with plasma status
fig = plt.figure(figsize = (16, 10))
fig.suptitle("Disruption prediction with shot : {}".format(shot_num))
gs = GridSpec(nrows = 2, ncols = 3)

# EFIT plot : betap, internal inductance, q95, plasma current
# plasma current
ax_ip = fig.add_subplot(gs[0,0])
ln1 = ax_ip.plot(plot_diag['time'], plot_diag['\\RC03'].abs(), label = 'Ip')

ax_iv = ax_ip.twinx()
ax_ip.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_ip.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_ip.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")

ln2 = ax_iv.plot(plot_diag['time'], plot_diag['\\VCM03'].abs() - plot_diag['\\RC03'].abs(), c = 'r', label = 'Iv')
lns = ln1 + ln2
labs = [l.get_label() for l in lns]
ax_ip.legend(lns, labs, loc = 'upper left')
ax_ip.set_ylabel("Ip")
ax_ip.set_xlim([tl,tr])

# q95
ax_q95 = fig.add_subplot(gs[1,0])
ax_q95.plot(plot_efit['time'], plot_efit['\\q95'], label = 'q95')
ax_q95.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_q95.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_q95.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_q95.set_ylim([0, 10.0])
ax_q95.set_ylabel("q95")
ax_q95.set_xlabel("time(unit:s)")
ax_q95.legend(loc = 'upper left')
ax_q95.set_xlim([tl,tr])

# ECE part
ax_ece = fig.add_subplot(gs[0,1])
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE67'].ewm(com=0.5).mean(), label = 'R=1.808m (Core)')
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE64'].ewm(com=0.5).mean(), label = 'R=1.863m')
ax_ece.plot(plot_ece['time'], plot_ece['\\ECE63'].ewm(com=0.5).mean(), label = 'R=1.883m')
ax_ece.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_ece.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_ece.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_ece.set_ylabel("ECE(unit:KeV)")
ax_ece.legend(loc = 'upper left')
ax_ece.set_xlim([tl,tr])

ax_tci = fig.add_subplot(gs[1,1])

if int(data_disrupt[data_disrupt.shot == shot_num].Year) == 2018:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci05'], label = 'TCI05(R=2.16m)')
    
elif int(data_disrupt[data_disrupt.shot == shot_num].Year) == 2019:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci03'], label = 'TCI03(R=1.91m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci04'], label = 'TCI04(R=2.04m)')   
    
else:
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci01'], label = 'TCI01(R=1.34m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci02'], label = 'TCI02(R=1.78m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci03'], label = 'TCI03(R=1.91m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci04'], label = 'TCI04(R=2.04m)')
    ax_tci.plot(plot_diag['time'], plot_diag['\\ne_tci05'], label = 'TCI05(R=2.16m)')
    
ax_tci.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_tci.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_tci.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_tci.set_ylabel("ne-TCI(unit:$10^{19}$ $m^{-3}$)")
ax_tci.set_xlabel("time(unit:s)")
ax_tci.legend(loc = 'upper left')
ax_tci.set_xlim([tl,tr])

# Diagnostic part
# Stored energy
ax_w = fig.add_subplot(gs[0,2])
ax_w.plot(plot_diag['time'], plot_diag['\\WTOT_DLM03'], label = 'Stored energy')
ax_w.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_w.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_w.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_w.legend(loc = 'upper left')
ax_w.set_xlim([tl,tr])

# Bolometer
ax_bol = fig.add_subplot(gs[1,2])
ax_bol.plot(plot_diag['time'], plot_diag['\\ax3_bolo02:FOO'] / plot_diag['\\ax3_bolo02:FOO'].abs().max(), label = 'AXUV bolometer')
ax_bol.axvline(x = t_warning, ymin = 0, ymax = 1, color = "black", linestyle = "dashed")
ax_bol.axvline(x = t_disrupt, ymin = 0, ymax = 1, color = "red", linestyle = "dashed")
ax_bol.axvline(x = t_current, ymin = 0, ymax = 1, color = "green", linestyle = "dashed")
ax_bol.set_xlabel("time(unit:s)")
ax_bol.legend(loc = 'upper left')
ax_bol.set_ylim([0.2,0.9])
ax_bol.set_xlim([tl,tr])

fig.tight_layout()
plt.show()
